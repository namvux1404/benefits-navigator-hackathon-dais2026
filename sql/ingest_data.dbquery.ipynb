-- %%
-- Step 1 — Create catalog and schema
-- CREATE CATALOG IF NOT EXISTS `benefits-navigator-hackathon`;

-- CREATE SCHEMA IF NOT EXISTS `benefits_navigator`.`trusted`;

-- Step 2 — Create facilities table
CREATE OR REPLACE TABLE `benefits_navigator`.`trusted`.`facilities` (
  `unique_id` STRING,
  `source_types` STRING,
  `source_ids` STRING,
  `source_content_id` STRING,
  `name` STRING,
  `organization_type` STRING,
  `content_table_id` STRING,
  `phone_numbers` STRING,
  `officialPhone` STRING,
  `email` STRING,
  `websites` STRING,
  `officialWebsite` STRING,
  `yearEstablished` STRING,
  `acceptsVolunteers` STRING,
  `facebookLink` STRING,
  `address_line1` STRING,
  `address_line2` STRING,
  `address_line3` STRING,
  `address_city` STRING,
  `address_stateOrRegion` STRING,
  `address_zipOrPostcode` STRING,
  `address_country` STRING,
  `address_countryCode` STRING,
  `countries` STRING,
  `facilityTypeId` STRING,
  `operatorTypeId` STRING,
  `affiliationTypeIds` STRING,
  `description` STRING,
  `area` STRING,
  `numberDoctors` STRING,
  `capacity` STRING,
  `specialties` STRING,
  `procedure` STRING,
  `equipment` STRING,
  `capability` STRING,
  `recency_of_page_update` STRING,
  `distinct_social_media_presence_count` STRING,
  `affiliated_staff_presence` STRING,
  `custom_logo_presence` STRING,
  `number_of_facts_about_the_organization` STRING,
  `post_metrics_most_recent_social_media_post_date` STRING,
  `post_metrics_post_count` STRING,
  `engagement_metrics_n_followers` STRING,
  `engagement_metrics_n_likes` STRING,
  `engagement_metrics_n_engagements` STRING,
  `source` STRING,
  `coordinates` STRING,
  `latitude` DOUBLE,
  `longitude` DOUBLE,
  `cluster_id` STRING,
  `source_urls` STRING
)
USING DELTA;

-- Step 3 — Create India PIN code directory table
CREATE OR REPLACE TABLE `benefits_navigator`.`trusted`.`india_post_pincode_directory` (
  `circlename` STRING,
  `regionname` STRING,
  `divisionname` STRING,
  `officename` STRING,
  `pincode` BIGINT,
  `officetype` STRING,
  `delivery` STRING,
  `district` STRING,
  `statename` STRING,
  `latitude` STRING,
  `longitude` STRING
)
USING DELTA;

-- Step 4 — Create NFHS-5 district health indicators table
CREATE OR REPLACE TABLE `benefits_navigator`.`trusted`.`nfhs_5_district_health_indicators` (
  `district_name` STRING,
  `state_ut` STRING,
  `households_surveyed` DOUBLE,
  `women_15_49_interviewed` DOUBLE,
  `men_15_54_interviewed` DOUBLE,
  `female_population_age_6_years_and_above_ever_schooled_pct` DOUBLE,
  `population_below_age_15_years_pct` DOUBLE,
  `sex_ratio_total_f_per_1000_m` DOUBLE,
  `sex_ratio_at_birth_5y_f_per_1000_m` STRING,
  `child_u5_whose_birth_was_civil_reg_pct` DOUBLE,
  `deaths_in_the_last_3_years_civil_reg_pct` STRING,
  `hh_electricity_pct` DOUBLE,
  `hh_improved_water_pct` DOUBLE,
  `hh_use_improved_sanitation_pct` DOUBLE,
  `households_using_clean_fuel_for_cooking_pct` DOUBLE,
  `households_using_iodized_salt_pct` DOUBLE,
  `hh_member_covered_health_insurance_pct` DOUBLE,
  `child_5y_who_attended_pre_primary_school_during_the_school_pct` STRING,
  `women_age_15_49_who_are_literate_pct` DOUBLE,
  `women_age_15_49_with_10_or_more_years_of_schooling_pct` DOUBLE,
  `w20_24_married_before_age_18_years_pct` STRING,
  `births_in_the_5_years_preceding_the_survey_that_are_birth_3_pct` STRING,
  `w15_19_who_were_already_mothers_or_pregnant_at_the_time_of_pct` STRING,
  `w15_24_who_use_menstrual_hygiene_pct` DOUBLE,
  `fp_cm_w15_49_any_method_pct` DOUBLE,
  `fp_cm_w15_49_modern_method_pct` DOUBLE,
  `fp_cm_w15_49_f_steril_pct` DOUBLE,
  `fp_cm_w15_49_m_steril_pct` DOUBLE,
  `fp_cm_w15_49_iud_pct` DOUBLE,
  `fp_cm_w15_49_pill_pct` DOUBLE,
  `fp_cm_w15_49_condom_pct` DOUBLE,
  `fp_cm_w15_49_injectables_pct` DOUBLE,
  `fp_unmet_total_cm_w15_49_7_pct` DOUBLE,
  `fp_unmet_spacing_cm_w15_49_7_pct` DOUBLE,
  `health_worker_ever_talked_to_female_non_users_about_family_pct` DOUBLE,
  `current_users_ever_told_about_side_effects_of_current_metho_pct` STRING,
  `mothers_who_had_an_anc_visit_in_the_first_trimester_lb5y_pct` STRING,
  `mothers_who_had_at_least_4_anc_visits_lb5y_pct` STRING,
  `mothers_whose_last_birth_was_protected_against_neo_tetanus_pct` STRING,
  `mothers_who_consumed_ifa_for_100_days_or_more_when_they_wer_pct` STRING,
  `mothers_who_consumed_ifa_for_180_days_or_more_when_they_wer_pct` STRING,
  `registered_pregnancies_for_which_the_mother_received_a_mcp_pct` STRING,
  `mothers_who_received_pnc_from_a_doctor_nurse_lhv_anm_midwif_pct` STRING,
  `average_out_of_pocket_expenditure_per_delivery_in_a_public_fac` STRING,
  `children_born_at_home_who_were_taken_to_a_health_facility_f_pct` STRING,
  `children_who_received_pnc_from_a_doctor_nurse_lhv_anm_midwi_pct` STRING,
  `institutional_birth_5y_pct` DOUBLE,
  `institutional_birth_in_public_facility_5y_pct` DOUBLE,
  `home_birth_that_were_conducted_by_skilled_hp_5y_10_pct` DOUBLE,
  `births_attended_by_skilled_hp_5y_10_pct` DOUBLE,
  `births_delivered_by_csection_5y_pct` DOUBLE,
  `births_in_a_private_fac_that_were_delivered_by_csection_5y_pct` STRING,
  `births_in_a_public_fac_that_were_delivered_by_csection_5y_pct` STRING,
  `child_12_23m_fully_vaccinated_based_on_information_from_eit_pct` STRING,
  `child_12_23m_fully_vaccinated_based_on_information_from_vax_pct` STRING,
  `child_12_23m_who_have_received_bcg_pct` STRING,
  `child_12_23m_who_have_received_3_doses_of_polio_vaccine_pct` STRING,
  `child_12_23m_who_have_received_3_doses_of_penta_or_dpt_vacc_pct` STRING,
  `child_12_23m_who_have_received_the_first_dose_of_mcv_mcv_pct` STRING,
  `child_24_35m_who_have_received_a_second_dose_of_mcv_mcv_pct` STRING,
  `child_12_23m_who_have_received_3_doses_of_rotavirus_vaccine_pct` STRING,
  `child_12_23m_who_have_received_3_doses_of_penta_or_hepatiti_pct` STRING,
  `child_9_35m_who_received_a_vit_a_in_the_last_6_months_pct` STRING,
  `child_12_23m_who_received_most_of_their_vaccinations_in_a_p_pct` STRING,
  `child_12_23m_who_received_most_of_their_vaccinations_in_a_2_pct` STRING,
  `prev_diarrhoea_2wk_child_u5_pct` DOUBLE,
  `children_with_diarrhoea_2wk_who_received_oral_rehydration_s_pct` STRING,
  `children_with_diarrhoea_2wk_who_received_zinc_child_u5_pct` STRING,
  `children_with_diarrhoea_2wk_taken_to_a_health_facility_or_h_pct` STRING,
  `children_prev_symptoms_of_acute_respiratory_infection_ari_2_pct` DOUBLE,
  `children_with_fever_or_symptoms_of_ari_2wk_taken_to_a_healt_pct` STRING,
  `children_under_age_3_years_breastfed_within_one_hour_of_bir_pct` STRING,
  `child_u6m_exclusively_breastfed_pct` STRING,
  `child_6_8m_receiving_solid_or_semi_solid_food_and_breastmil_pct` STRING,
  `breastfeeding_child_6_23m_receiving_an_adequate_diet16_17_pct` STRING,
  `non_breastfeeding_child_6_23m_receiving_an_adequate_diet16_pct` STRING,
  `total_child_6_23m_receiving_an_adequate_diet16_17_pct` STRING,
  `child_u5_who_are_stunted_height_for_age_18_pct` STRING,
  `child_u5_who_are_wasted_weight_for_height_18_pct` STRING,
  `child_u5_who_are_severe_wasted_weight_for_height_19_pct` STRING,
  `child_u5_who_are_underweight_weight_for_age_18_pct` STRING,
  `child_u5_who_are_overweight_weight_for_height_20_pct` STRING,
  `women_age_15_49_years_whose_bmi_bmi_is_underweight_bmi_lt_1_pct` DOUBLE,
  `women_age_15_49_years_who_are_overweight_obese_bmi_gte_25_0_pct` DOUBLE,
  `women_age_15_49_years_who_have_high_risk_whr_gte_0_85_pct` DOUBLE,
  `child_6_59m_who_are_anaemic_lt_11_0_g_dl_22_pct` STRING,
  `non_pregnant_w15_49_who_are_anaemic_lt_12_0_g_dl_22_pct` DOUBLE,
  `pregnant_w15_49_who_are_anaemic_lt_11_0_g_dl_22_pct` STRING,
  `all_w15_49_who_are_anaemic_pct` DOUBLE,
  `all_w15_19_who_are_anaemic_pct` STRING,
  `women_age_15_years_and_above_with_high_141_160_mg_dl_blood_pct` DOUBLE,
  `w15_plus_with_very_high_gt_160_mg_dl_blood_sugar_pct` DOUBLE,
  `w15_plus_with_high_or_very_high_gt_140_mg_dl_blood_sugar_or_pct` DOUBLE,
  `m15_plus_with_high_141_160_mg_dl_blood_sugar_pct` DOUBLE,
  `men_age_15_years_and_above_with_very_high_gt_160_mg_dl_bloo_pct` DOUBLE,
  `m15_plus_with_high_or_very_high_gt_140_mg_dl_blood_sugar_or_pct` DOUBLE,
  `w15_plus_with_mildly_high_bp_sys_140_159_mmhg_and_or_dia_90_pct` DOUBLE,
  `w15_plus_with_moderately_or_severely_high_bp_sys_gte_160_mm_pct` DOUBLE,
  `w15_plus_with_high_bp_sys_gte_140_mmhg_and_or_dia_gte_90_mm_pct` DOUBLE,
  `m15_plus_with_mildly_high_bp_sys_140_159_mmhg_and_or_dia_90_pct` DOUBLE,
  `m15_plus_with_moderately_or_severely_high_bp_sys_gte_160_mm_pct` DOUBLE,
  `m15_plus_with_high_bp_sys_gte_140_mmhg_and_or_dia_gte_90_mm_pct` DOUBLE,
  `women_age_30_49_years_ever_undergone_a_cervical_screen_pct` DOUBLE,
  `women_age_30_49_years_ever_undergone_a_breast_exam_pct` DOUBLE,
  `women_age_30_49_years_ever_undergone_an_oral_cancer_exam_pct` DOUBLE,
  `w15_plus_who_use_any_kind_of_tobacco_pct` DOUBLE,
  `m15_plus_who_use_any_kind_of_tobacco_pct` DOUBLE,
  `w15_plus_who_consume_alcohol_pct` DOUBLE,
  `m15_plus_who_consume_alcohol_pct` DOUBLE
)
USING DELTA;


-- Load data

-- Step 5 — Create curated PIN-to-district lookup table

-- Create this after loading data into india_post_pincode_directory.

CREATE OR REPLACE TABLE `benefits_navigator`.`trusted`.`pincode_district_lookup`
USING DELTA
AS
SELECT
  pincode,
  upper(trim(district)) AS district_norm,
  upper(trim(statename)) AS state_norm,
  COUNT(*) AS post_office_count,
  COUNT(DISTINCT officename) AS unique_post_offices,
  MIN(latitude) AS sample_latitude,
  MIN(longitude) AS sample_longitude
FROM `benefits_navigator`.`trusted`.`india_post_pincode_directory`
GROUP BY
  pincode,
  upper(trim(district)),
  upper(trim(statename));

-- Step 6 — Create support pathways table

-- This replaces the old benefit-program rules table.
CREATE OR REPLACE TABLE `benefits_navigator`.`trusted`.`support_pathways` (
  `pathway_id` STRING,
  `pathway_name` STRING,
  `category` STRING,
  `trigger_condition` STRING,
  `recommended_action` STRING,
  `data_sources` STRING,
  `active_flag` BOOLEAN
)
USING DELTA;

-- Step 7 — Insert support pathway rules

-- DELETE FROM `benefits_navigator`.`trusted`.`support_pathways`;

INSERT INTO `benefits_navigator`.`trusted`.`support_pathways` VALUES
(
  'maternal_care',
  'Maternal Health Support',
  'maternal_health',
  'pregnant=true OR recently_delivered=true',
  'Find nearby facilities with maternal, ANC, delivery, or postnatal services. Review district ANC and institutional birth indicators.',
  'facilities,nfhs_5_district_health_indicators,pincode_district_lookup',
  true
),
(
  'child_nutrition',
  'Child Nutrition Support',
  'child_health',
  'child_under_5=true OR nutrition_need=true',
  'Review district stunting, wasting, underweight, diarrhea, and anemia indicators. Recommend nearby child-health or nutrition-related facilities.',
  'facilities,nfhs_5_district_health_indicators,pincode_district_lookup',
  true
),
(
  'immunization',
  'Child Immunization Support',
  'child_health',
  'child_age_months BETWEEN 0 AND 35',
  'Review district vaccination indicators and suggest nearby facilities that may support child immunization or pediatric care.',
  'facilities,nfhs_5_district_health_indicators,pincode_district_lookup',
  true
),
(
  'health_insurance_awareness',
  'Health Insurance Awareness',
  'health_access',
  'uninsured=true OR low_income=true',
  'Show district health-insurance coverage context and guide the user to ask local facilities or public-health offices about available coverage options.',
  'nfhs_5_district_health_indicators,facilities',
  true
),
(
  'household_health_risk',
  'Household Health Risk Support',
  'household_conditions',
  'water_sanitation_need=true OR child_diarrhea_risk=true',
  'Review district water, sanitation, clean fuel, and diarrhea indicators. Provide prevention-oriented next steps and nearby facility referrals.',
  'nfhs_5_district_health_indicators,facilities',
  true
),
(
  'women_preventive_screening',
  'Women Preventive Screening Support',
  'preventive_health',
  'adult_woman=true OR screening_need=true',
  'Review district cervical, breast, and oral cancer screening indicators. Recommend nearby facilities and questions to ask during visit.',
  'nfhs_5_district_health_indicators,facilities',
  true
);

-- -- Step 8 — Validate tables
SHOW TABLES IN `benefits_navigator`.`trusted`;
SELECT COUNT(*) AS facility_count
FROM `benefits_navigator`.`trusted`.`facilities`;
SELECT COUNT(*) AS pincode_rows
FROM `benefits_navigator`.`trusted`.`india_post_pincode_directory`;
SELECT COUNT(*) AS nfhs_district_rows
FROM `benefits_navigator`.`trusted`.`nfhs_5_district_health_indicators`;
SELECT COUNT(*) AS support_pathways
FROM `benefits_navigator`.`trusted`.`support_pathways`;
