-- %%
INSERT INTO `benefits_navigator`.`trusted`.facilities
SELECT * FROM databricks_virtue_foundation_dataset_dais_2026.virtue_foundation_dataset.facilities;

INSERT INTO `benefits_navigator`.`trusted`.india_post_pincode_directory
SELECT * FROM databricks_virtue_foundation_dataset_dais_2026.virtue_foundation_dataset.india_post_pincode_directory;

INSERT INTO `benefits_navigator`.`trusted`.nfhs_5_district_health_indicators
SELECT * FROM databricks_virtue_foundation_dataset_dais_2026.virtue_foundation_dataset.nfhs_5_district_health_indicators;
